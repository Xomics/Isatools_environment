# %%
# biopy-isatab Python parser for ISA-tab

from bcbio import isatab

rec = isatab.parse(input_dir)
print(rec.metadata)
print('\n\n')
print(rec.ontology_refs)
print('\n\n')
print(rec.publications)
print('\n\n')
print(rec.studies)

# %%
# Import isa-files from Metabolights
# (connection with Metabolights is necessary)

from isatools.net import mtbls as MTBLS

tmp_dir = MTBLS.get('MTBLS1')

# %%
# Reading ISA-Tab from local files
# (These are downloaded from Metabolights)

import isatools
import sys
import os
from isatools import isatab

with open(os.path.join(input_dir)) as fp:
    ISA = isatab.load(fp)

# Studies   
studies = ISA.studies
print(len(studies))

# First study
study_1 = ISA.studies[0]

# Title of the first study object 
study_1.title

# Description of the first study object in ISA Investigation object
study_1.description
# Out:
# 2021-03-16 11:31:41,599 [WARNING]: isatab.py(create_from_df:5577) >> Duplicate characteristic found for material, skipping adding to material object
# 2021-03-16 11:31:41,599 [WARNING]: isatab.py(create_from_df:5577) >> Duplicate characteristic found for material, skipping adding to material object
# 2021-03-16 11:31:41,612 [WARNING]: isatab.py(create_from_df:5577) >> Duplicate characteristic found for material, skipping adding to material object
# 2021-03-16 11:31:41,616 [WARNING]: isatab.py(create_from_df:5577) >> Duplicate characteristic found for material, skipping adding to material object
# 1
# 'Mitochondria are highly dynamic organelles undergoing fusion, fission and degradation. Although mitochondria are known to be essential for cellular metabolism, it is not fully understood how mitochondrial dynamics affect cellular metabolism. We previously identified a mouse gene, transmembrane protein 135 (TMEM135) that plays a role in the regulation of mitochondrial dynamics. Mice with mutant Tmem135 (Tmem135FUN025/FUN025) show accelerated aging phenotypes and age-related pathologies in the retina including the retinal pigment epithelium (RPE). We also generated a transgenic mouse line globally overexpressing the Tmem135 gene (Tmem135 TG). In several tissues and cells that we studied such as the retina, heart and fibroblast cells, we observed that the Tmem135 mutation causes elongated mitochondria, while over-expression of Tmem135 results in fragmented mitochondria. These unique mouse models allow us to test how abnormal mitochondrial dynamics affect metabolic signatures of tissues and cells. In this study, we identified metabolic changes in primary RPE cell cultures as well as tissues isolated from Tmem135FUN025/FUN025 mice (fusion > fission) and Tmem135 TG mice (fusion < fission) using nuclear magnetic resonance (NMR) spectroscopy. Metabolomics analysis revealed a tissue-dependent response to alterations to Tmem135 whereby, significant metabolic changes were observed in heart in both mutant and TG mice as compared to WT while negligible effects were observed in cerebellum and hippocampus. We also observed changes in Tmem135FUN025/FUN025 and Tmem135 TG RPE cells associated with osmosis, glucose metabolism and phospholipid metabolism. Significant depletion of NAD+ was detected in both Tmem135FUN025/FUN025 and Tmem135 TG RPE cells, indicating that imbalance in mitochondrial dynamics to both directions lowers the cellular NAD+ level. Thus, we have identified metabolomic changes associated with imbalanced mitochondrial dynamics in heart tissue and RPE cells which can likely lead to functional abnormalities.'

# %%
# Protocols declared in the first study


protocols = study_1.protocols
print('Number of protocols = ', len(protocols), '\n\n')
protocol_1 = protocols[0]
print(protocol_1, '\n\n')
print(protocol_1.description)

protocols_descriptions = [protocol.description for protocol in protocols]
# Out:
# Number of protocols =  7
#
#
# Protocol(
#     name=Sample collection
#     protocol_type=Sample collection
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# )
#
#
# <p>Animals and brain sample preparation</p><p>Young/adult (3 month) and aged (24 month) male C57BL/6 mice were used. Experiments were conducted under the guidelines of the Scientific Procedure Animal Act (1986) of the U.K. and approved by the Ethical Review Committee of the University of East Anglia, Norwich (AWERB ref: 70/7583) or at the Ce.S.A.L (Centro Stabulazione Animali da Laboratorio, University of Florence, Italy) under the approval of the Italian Ministry of Health (No. 54/2014-B) and the Animal Subjects Review Board of the University of Florence. Mice (Envigo, Varese, Italy or Charles River, UK) were provided with food and water ad libitum. Environmental temperature was kept at 23Â±1 Â°C with a 12 h light/dark cycle. All efforts were made to minimize animal suffering and to reduce the number of animals used.</p><p><br></p><p>Faecal material preparation and FMT regime</p><p>Faecal material was collected from adult and aged mice and placed into Eppendorf tubes containing 500 ml of freezing solution (sterile saline solution with 12.5% glycerol), tubes were left on ice for 60 min and later homogenized for 2 min on ice using a hand-held electric pellet pestle device with sterile, re-usable pestles. When fully homogenized, the suspended pellets were frozen and stored at -80Â°C until utilized for the FMT procedure. To this end, mice were randomized into the following treatment groups (n=12 per group): control (no antibiotic treatment, no FMT); FMT-adult (antibiotic treatment followed by FMT from young age-matched donors), FMT-aged (antibiotic treatments followed by FMT from aged donors). It is made available under a CC-BY 4.0 International license. was not peer-reviewed) is the author/funder, who has granted bioRxiv a license to display the preprint in perpetuity. bioRxiv preprint first posted online Dec. 6, 2019; doi: http://dx.doi.org/10.1101/866459. The copyright holder for this preprint (which 15 Antibiotic mix was prepared in autoclaved drinking water and provided in 250 ml clear glass slippers or suspended in 1% carboxymethylcellulose sodium salt (CMC; Sigma-Aldrich) and administered by oral gavage. The antibiotic/anti-fungal regime was as follows: day 1-3 mice were gavaged daily with anti-fungal treatment with amphotericin B 1 mg kg-1, day 4-17 mice received a daily gavage of metronidazole 100 mg kg-1 while the antibiotic mix (ampicillin 1 g L-1, vancomycin 0.5 g L-1 and neomicin 1 g L-1 was added to drinking water), day 18-24 daily oral gavage with ampicillin 1 g L-1, vancomycin 0.5 g L-1, neomicin 1 g L-1, metronidazole 100 mg kg-amphotericin B 1 mg kg-1. FMT was carried out via oral gavage with a faecal suspension (100 mg ml-1) in a final volume of 150 ml. FMT was performed six times on days 24-28 and 35 from the beginning of antibiotic regime.&nbsp;</p>

# %%
assays = study_1.assays
print("Number of assays = ", len(assays), '\n\n')
assay1 = assays[0]
print(assay1)
print(assay1.measurement_type, '\n\n')


# Assay Measurement and Technology Types that are used in this study
[
    assay.measurement_type.term + " using " + assay.technology_type.term for assay in assays
]

# %%
# ISA Study source material

[source.name for source in study_1.sources]

study_1.sources[0].name = 'TEST'

# %%
# Get all characteristics of the first Source Object

first_source_characeristics = study_1.sources[0].characteristics
print('Number of characteristics = ', len(first_source_characeristics))

print(first_source_characeristics[0])
# Out:
# Number of characteristics =  4
# Characteristic(
#     category=Organism
#     value=Mus musculus
#     unit=
#     comments=0 Comment objects
# )

# %%
# Change the category term of the first characteristic
first_source_characeristics[0].category.term = 'TEST'

print(first_source_characeristics[0])
# Out:
# Characteristic(
#     category=TEST
#     value=Mus musculus
#     unit=
#     comments=0 Comment objects
# )

# %%
# Porperties associated with first ISA Study sourcee

[char.category.term for char in first_source_characeristics]

[char.value.term for char in first_source_characeristics]

# %%
# Export ISA files with adjustments

isatab.dump(ISA, output_dir)

# %%
print(type(ISA.studies[0]))

print(type(ISA.studies[0].assays[0]))
# Out:
# <class 'isatools.model.Study'>
# <class 'isatools.model.Assay'>

# %%
from local_package_installer.local_package_installer import install_local
install_local('isatools')

# %%
# Export ISA files with adjustments

isatab.dump(ISA, output_dir)
# Out:
# 2021-03-15 09:54:33,784 [INFO]: isatab.py(write_assay_table_files:1383) >> No paths found, skipping writing assay file
# isatools.model.Investigation(identifier='1552652580231', filename='', title='Investigation', submission_date='', public_release_date='2021-02-12', ontology_source_references=[isatools.model.OntologySource(name='OBI', file='http://data.bioontology.org/ontologies/OBI', version='29', description='Ontology for Biomedical Investigations', comments=[]), isatools.model.OntologySource(name='EFO', file='', version='', description='', comments=[]), isatools.model.OntologySource(name='MTBLS', file='https://www.ebi.ac.uk/metabolights/', version='1.0', description='Metabolights Ontology', comments=[]), isatools.model.OntologySource(name='CHMO', file='', version='', description='', comments=[]), isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[])], publications=[], contacts=[], studies=[isatools.model.Study(filename='s_MTBLS1437.txt', identifier='MTBLS1437', title='Faecal microbiota transplant from aged donor mice into young recipients affects', description='Shifts in microbiota composition in ageing affect a variety of systems, including the central', submission_date='', public_release_date='2021-02-12', contacts=[isatools.model.Person(last_name='Le Gall', first_name='Gwenaelle', mid_initials='', email='gwenaelle.legalln@gmail.com', phone='00447914713345', fax='', address='Norwich Medical School
# Faculty of Medicine and Health Sciences
# Floor 2, Bob Champion Research and Educational Building, James Watson Road,
# University of East Anglia, Norwich Research Park, NORWICH, NR4 7UQ', affiliation='Nutrition department', roles=[isatools.model.OntologyAnnotation(term='Subinvestigator', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C54622', comments=[])], comments=[])], design_descriptors=[isatools.model.OntologyAnnotation(term='Nuclear magnetic resonance spectroscopy', term_source=isatools.model.OntologySource(name='CHMO', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/CHMO_0000591', comments=[]), isatools.model.OntologyAnnotation(term='one-dimensional nuclear magnetic resonance spectroscopy', term_source=isatools.model.OntologySource(name='CHMO', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/CHMO_0000592', comments=[]), isatools.model.OntologyAnnotation(term='two-dimensional nuclear magnetic resonance spectroscopy', term_source=isatools.model.OntologySource(name='CHMO', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/CHMO_0000598', comments=[]), isatools.model.OntologyAnnotation(term='untargeted metabolites', term_source=isatools.model.OntologySource(name='MTBLS', file='https://www.ebi.ac.uk/metabolights/', version='1.0', description='Metabolights Ontology', comments=[]), term_accession='http://www.ebi.ac.uk/metabolights/ontology/MTBLS_000279', comments=[])], publications=[isatools.model.Publication(pubmed_id='33004079', doi='10.1186/s40168-020-00914-w', author_list='Dâ€™Amato Alfonsina, Di Cesare Mannelli Lorenzo, Lucarini Elena, Man Angela L., Le Gall Gwenaelle, Branca Jacopo J. V., Ghelardini Carla, Amedei Amedeo, Bertelli Eugenio, Regoli Mari, Pacini Alessandra, Luciani Giulia, Gallina Pasquale, Altera Annalisa, Narbad Arjan, Gulisano Massimo, Hoyles Lesley, Vauzour David, Nicoletti Claudio', title='Faecal microbiota transplant from aged donor mice affects spatial learning and memory via modulating hippocampal synaptic plasticity- and neurotransmission-related proteins in young recipients', status=isatools.model.OntologyAnnotation(term='Published', term_source=isatools.model.OntologySource(name='EFO', file='', version='', description='', comments=[]), term_accession='http://www.ebi.ac.uk/efo/EFO_0001796', comments=[]), comments=[])], factors=[isatools.model.StudyFactor(name='microbiota', factor_type=isatools.model.OntologyAnnotation(term='Microbiota', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_408170', comments=[]), comments=[])], protocols=[isatools.model.Protocol(name='Sample collection', protocol_type=isatools.model.OntologyAnnotation(term='Sample collection', term_source=None, term_accession='', comments=[]), uri='', version='', parameters=[isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='', term_source=None, term_accession='', comments=[]), comments=[])], components=[], comments=[]), isatools.model.Protocol(name='Extraction', protocol_type=isatools.model.OntologyAnnotation(term='Extraction', term_source=None, term_accession='', comments=[]), uri='', version='', parameters=[isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='Extraction Method', term_source=None, term_accession='', comments=[]), comments=[])], components=[], comments=[]), isatools.model.Protocol(name='NMR sample', protocol_type=isatools.model.OntologyAnnotation(term='NMR sample', term_source=None, term_accession='', comments=[]), uri='', version='', parameters=[isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnnotation(term='NMR tube type', term_source=None, term_accession='', comments=[]), comments=[]), isatools.model.ProtocolParameter(parameter_name=isatools.model.OntologyAnno ...
#     name=Extraction
#     protocol_type=Extraction
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.Sample(name='MS 1_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 8 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[]), isatools.model.Sample(name='MS 2_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 9 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[]), isatools.model.Sample(name='MS 3_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 10 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnota ...
#     name=NMR sample
#     protocol_type=NMR sample
#     uri=
#     version=
#     parameters=4 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[], outputs=[]), isatools.model.Process(id="". name="None", executes_protocol=Protocol(
#     name=NMR spectroscopy
#     protocol_type=NMR spectroscopy
#     uri=
#     version=
#     parameters=5 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[], outputs=[]), isatools.model.Process(id="". name="MS 1_2601", executes_protocol=Protocol(
#     name=NMR assay
#     protocol_type=NMR assay
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.DataFile(filename='ms/1_2601/acqus', label='Acquisition Parameter Data File', generated_from=[isatools.model.Sample(name='MS 1_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 8 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])], comments=[])], outputs=[]), isatools.model.Process(id="". name="MS 2_2601", executes_protocol=Protocol(
#     name=NMR assay
#     protocol_type=NMR assay
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.DataFile(filename='ms/2_2601/acqus', label='Acquisition Parameter Data File', generated_from=[isatools.model.Sample(name='MS 2_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 9 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])], comments=[])], outputs=[]), isatools.model.Process(id="". name="MS 3_2601", executes_protocol=Protocol(
#     name=NMR assay
#     protocol_type=NMR assay
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.DataFile(filename='ms/3_2601/acqus', label='Acquisition Parameter Data File', generated_from=[isatools.model.Sample(name='MS 3_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 10 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])], comments=[])], outputs=[]), isatools.model.Process(id="". name="MS 4_2601", executes_protocol=Protocol(
#     name=NMR assay
#     protocol_type=NMR assay
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.DataFile(filename='ms/4_2601/acqus', label='Acquisition Parameter Data File', generated_from=[isatools.model.Sample(name='MS 4_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 11 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])], comments=[])], outputs=[]), isatools.model.Process(id="". name="MS 5_2601", executes_protocol=Protocol(
#     name=NMR assay
#     protocol_type=NMR assay
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.DataFile(filename='ms/5_2601/acqus', label='Acquisition Parameter Data File', generated_from=[isatools.model.Sample(name='MS 5_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 12 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])], comments=[])], outputs=[]), isatools.model.Process(id="". name="MS 6_2601", executes_protocol=Protocol(
#     name=NMR assay
#     protocol_type=NMR assay
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.DataFile(filename='ms/6_2601/acqus', label='Acquisition Parameter Data File', generated_from=[isatools.model.Sample(name='MS 6_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 13 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])], comments=[])], outputs=[]), isatools.model.Process(id="". name="MS 7_2601", executes_protocol=Protocol(
#     name=NMR assay
#     protocol_type=NMR assay
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.DataFile(filename='ms/7_2601/acqus', label='Acquisition Parameter Data File', generated_from=[isatools.model.Sample(name='MS 7_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 14 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])], comments=[])], outputs=[]), isatools.model.Process(id="". name="MS 8_2601", executes_protocol=Protocol(
#     name=NMR assay
#     protocol_type=NMR assay
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.DataFile(filename='ms/8_2601/acqus', label='Acquisition Parameter Data File', generated_from=[isatools.model.Sample(name='MS 8_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 15 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])], comments=[])], outputs=[]), isatools.model.Process(id="". name="MS 9_2601", executes_protocol=Protocol(
#     name=NMR assay
#     protocol_type=NMR assay
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.DataFile(filename='ms/9_2601/acqus', label='Acquisition Parameter Data File', generated_from=[isatools.model.Sample(name='MS 9_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 16 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])], comments=[])], outputs=[]), isatools.model.Process(id="". name="MS 10_2601", executes_protocol=Protocol(
#     name=NMR assay
#     protocol_type=NMR assay
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.DataFile(filename='ms/10_2601/acqus', label='Acquisition Parameter Data File', generated_from=[isatools.model.Sample(name='MS 10_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 1 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])], comments=[])], outputs=[]), isatools.model.Process(id="". name="MS 11_2601", executes_protocol=Protocol(
#     name=NMR assay
#     protocol_type=NMR assay
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.DataFile(filename='ms/11_2601/acqus', label='Acquisition Parameter Data File', generated_from=[isatools.model.Sample(name='MS 11_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 2 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])], comments=[])], outputs=[]), isatools.model.Process(id="". name="MS 12_2601", executes_protocol=Protocol(
#     name=NMR assay
#     protocol_type=NMR assay
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.DataFile(filename='ms/12_2601/acqus', label='Acquisition Parameter Data File', generated_from=[isatools.model.Sample(name='MS 12_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 3 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])], comments=[])], outputs=[]), isatools.model.Process(id="". name="MS 13_2601", executes_protocol=Protocol(
#     name=NMR assay
#     protocol_type=NMR assay
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.DataFile(filename='ms/13_2601/acqus', label='Acquisition Parameter Data File', generated_from=[isatools.model.Sample(name='MS 13_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 4 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])], comments=[])], outputs=[]), isatools.model.Process(id="". name="MS 14_2601", executes_protocol=Protocol(
#     name=NMR assay
#     protocol_type=NMR assay
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.DataFile(filename='ms/14_2601/acqus', label='Acquisition Parameter Data File', generated_from=[isatools.model.Sample(name='MS 14_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 5 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])], comments=[])], outputs=[]), isatools.model.Process(id="". name="MS 15_2601", executes_protocol=Protocol(
#     name=NMR assay
#     protocol_type=NMR assay
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.DataFile(filename='ms/15_2601/acqus', label='Acquisition Parameter Data File', generated_from=[isatools.model.Sample(name='MS 15_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 6 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])], comments=[])], outputs=[]), isatools.model.Process(id="". name="MS 16_2601", executes_protocol=Protocol(
#     name=NMR assay
#     protocol_type=NMR assay
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.DataFile(filename='ms/16_2601/acqus', label='Acquisition Parameter Data File', generated_from=[isatools.model.Sample(name='MS 16_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 7 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])], comments=[])], outputs=[]), isatools.model.Process(id="". name="", executes_protocol=Protocol(
#     name=Data transformation
#     protocol_type=Data transformation
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.DataFile(filename='ms/1_2601/fid', label='Free Induction Decay Data File', generated_from=[isatools.model.Sample(name='MS 1_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 8 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])], comments=[]), isatools.model.DataFile(filename='ms/2_2601/fid', label='Free Induction Decay Data File', generated_from=[isatools.model.Sample(name='MS 2_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 9 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])], comments=[]), isatools.model.DataFile(filename='ms/3_2601/fid', label='Free Induction Decay Data File', generated_from=[isatools.model.Sample(name='MS 3_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 10 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments= ...
#     name=Sample collection
#     protocol_type=Sample collection
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.Source(name='Ms 8 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], outputs=[isatools.model.Sample(name='MS 1_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 8 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])]), isatools.model.Process(id="". name="None", executes_protocol=Protocol(
#     name=Sample collection
#     protocol_type=Sample collection
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ...
#     name=Sample collection
#     protocol_type=Sample collection
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.Source(name='Ms 3 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], outputs=[isatools.model.Sample(name='MS 12_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 3 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])]), isatools.model.Process(id="". name="None", executes_protocol=Protocol(
#     name=Sample collection
#     protocol_type=Sample collection
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.Source(name='Ms 4 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], outputs=[isatools.model.Sample(name='MS 13_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 4 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])]), isatools.model.Process(id="". name="None", executes_protocol=Protocol(
#     name=Sample collection
#     protocol_type=Sample collection
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.Source(name='Ms 5 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], outputs=[isatools.model.Sample(name='MS 14_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 5 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])]), isatools.model.Process(id="". name="None", executes_protocol=Protocol(
#     name=Sample collection
#     protocol_type=Sample collection
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.Source(name='Ms 6 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], outputs=[isatools.model.Sample(name='MS 15_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 6 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])]), isatools.model.Process(id="". name="None", executes_protocol=Protocol(
#     name=Sample collection
#     protocol_type=Sample collection
#     uri=
#     version=
#     parameters=1 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[isatools.model.Source(name='Ms 7 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], outputs=[isatools.model.Sample(name='MS 16_2601', characteristics=[], factor_values=[], derives_from=[isatools.model.Source(name='Ms 7 2601', characteristics=[isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Mus musculus', term_source=isatools.model.OntologySource(name='NCBITAXON', file='', version='2021-02-12', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCBITaxon_10090', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), value=isatools.model.OntologyAnnotation(term='Feces', term_source=isatools.model.OntologySource(name='NCIT', file='', version='', description='', comments=[]), term_accession='http://purl.obolibrary.org/obo/NCIT_C13234', comments=[]), unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[]), isatools.model.Characteristic(category=isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), value='', unit=None, comments=[])], comments=[])], comments=[])])], other_material=[], characteristic_categories=[isatools.model.OntologyAnnotation(term='Organism', term_source=None, term_accession='', comments=[]), isatools.model.OntologyAnnotation(term='Organism part', term_source=None, term_accession='', comments=[]), isatools.model.OntologyAnnotation(term='Sample type', term_source=None, term_accession='', comments=[]), isatools.model.OntologyAnnotation(term='Variant', term_source=None, term_accession='', comments=[])], comments=[], units=[])], comments=[isatools.model.Comment(name='Created With Configuration', value='MetaboLightsConfig20150707'), isatools.model.Comment(name='Last Opened With Configuration', value='MetaboLightsConfig20150707')])

# %%
import json
from isatools.isajson import ISAJSONEncoder
test = json.dumps(ISA, cls=ISAJSONEncoder, sort_keys=True, indent=4, separators=(',', ': '))
print(type(test))
# Out:
# <class 'str'>

# %%
with open('test.json', 'w') as json_file:
    json_file.write(test)

# %%
ISA.studies[0].description
# Out:
# 'TEST'

# %%
ISA.studies[0].assays[0]
# Out:
# isatools.model.Assay(measurement_type=isatools.model.OntologyAnnotation(term='metabolite profiling', term_source=isatools.model.OntologySource(name='OBI', file='http://data.bioontology.org/ontologies/OBI', version='29', description='Ontology for Biomedical Investigations', comments=[]), term_accession='http://purl.obolibrary.org/obo/OBI_0000366', comments=[]), technology_type=isatools.model.OntologyAnnotation(term='mass spectrometry', term_source=isatools.model.OntologySource(name='OBI', file='http://data.bioontology.org/ontologies/OBI', version='29', description='Ontology for Biomedical Investigations', comments=[]), term_accession='http://purl.obolibrary.org/obo/OBI_0000470', comments=[]), technology_platform='Liquid Chromatography MS - positive - reverse phase', filename='a_MTBLS2390_LC-MS_positive_reverse-phase_metabolite_profiling.txt', data_files=[isatools.model.DataFile(filename='m_MTBLS2390_LC-MS_positive_reverse-phase_metabolite_profiling_v2_maf.tsv', label='Metabolite Assignment File', generated_from=[], comments=[])], samples=[], process_sequence=[isatools.model.Process(id="". name="None", executes_protocol=Protocol(
#     name=Extraction
#     protocol_type=Extraction
#     uri=
#     version=
#     parameters=2 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[], outputs=[]), isatools.model.Process(id="". name="None", executes_protocol=Protocol(
#     name=Chromatography
#     protocol_type=Chromatography
#     uri=
#     version=
#     parameters=5 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[], outputs=[]), isatools.model.Process(id="". name="", executes_protocol=Protocol(
#     name=Mass spectrometry
#     protocol_type=Mass spectrometry
#     uri=
#     version=
#     parameters=5 ProtocolParameter objects
#     components=0 OntologyAnnotation objects
#     comments=0 Comment objects
# ), date="None", performer="None", inputs=[], outputs=[isatools.model.DataFile(filename='m_MTBLS2390_LC-MS_positive_reverse-phase_metabolite_profiling_v2_maf.tsv', label='Metabolite Assignment File', generated_from=[], comments=[])])], other_material=[], characteristic_categories=[isatools.model.OntologyAnnotation(term='Label', term_source=None, term_accession='', comments=[])], comments=[], units=[])

# %%
Assay = (type(ISA.studies[0].assays[0]))

class Student(Assay):
    def add_comment2(self):
        return len(self)

# %%
test = Student('Test', 'Test2')
test2 = Student.add_comment2('test')

print(test2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f5bbdd1698e8> in <module>
# ----> 1 test = Student('Test', 'Test2')
#       2 test2 = Student.add_comment2('test')
#       3
#       4 print(test2)
#
# NameError: name 'Student' is not defined

# %%
Assay1 = (ISA.studies[0].assays[0])

Assay2 = (ISA.studies[0].assays[1])

print(Assay1)
print(Assay2)
# Out:
# Assay(
#     measurement_type=metabolite profiling
#     technology_type=mass spectrometry
#     technology_platform=Liquid Chromatography MS - positive - reverse phase
#     filename=a_MTBLS2390_LC-MS_positive_reverse-phase_metabolite_profiling.txt
#     data_files=1 DataFile objects
#     samples=0 Sample objects
#     process_sequence=3 Process objects
#     other_material=0 Material objects
#     characteristic_categories=1 OntologyAnnots
#     comments=0 Comment objects
#     units=0 Unit objects
# )
# Assay(
#     measurement_type=metabolite profiling
#     technology_type=mass spectrometry
#     technology_platform=Liquid Chromatography MS - negative - reverse phase
#     filename=a_MTBLS2390_LC-MS_negative_reverse-phase_metabolite_profiling.txt
#     data_files=1 DataFile objects
#     samples=0 Sample objects
#     process_sequence=3 Process objects
#     other_material=0 Material objects
#     characteristic_categories=1 OntologyAnnots
#     comments=0 Comment objects
#     units=0 Unit objects
# )
